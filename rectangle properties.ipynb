# %%
def rectangle_properties(length,width):
    area=length*width
    perimeter=2*(length+width)
    return area,perimeter
length=10
width=5
area,perimeter=rectangle_properties(length,width)
print(f"the area of the rectangle is {area}sq units")
print(f"the perimeter of the rectangle is {perimeter} units")
# Out:
# the area of the rectangle is 50sq units
# the perimeter of the rectangle is 30 units
